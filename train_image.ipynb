# %% [markdown]
# ### 任务1:微调在ImageNet上预训练的卷积神经网络实现鸟类识别
#
# 下面是使用PyTorch实现在ImageNet上预训练的ResNet-18模型进行鸟类识别的代码示例：

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torch.utils.tensorboard import SummaryWriter

# %%
#加载数据集
from dataset_image import CUB
import transforms
from torch.utils.data import DataLoader
import time

def dataloader(IMAGE_SIZE,batch_size):

    time1 = time.time()
    IMAGE_SIZE = IMAGE_SIZE
    TRAIN_MEAN = [0.48560741861744905, 0.49941626449353244, 0.43237713785804116]
    TRAIN_STD = [0.2321024260764962, 0.22770540015765814, 0.2665100547329813]
    TEST_MEAN = [0.4862169586881995, 0.4998156522834164, 0.4311430419332438]
    TEST_STD = [0.23264268069040475, 0.22781080253662814, 0.26667253517177186]

    path = 'CUB_200_2011/CUB_200_2011'
    train_transforms = transforms.Compose([
            transforms.ToCVImage(),
            transforms.RandomResizedCrop(IMAGE_SIZE),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(TRAIN_MEAN, TRAIN_STD)
        ])

    test_transforms = transforms.Compose([
        transforms.ToCVImage(),
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(TEST_MEAN,TEST_STD)
        ])

    train_dataset = CUB(
            path,
            train=True,
            transform=train_transforms,
            target_transform=None
        )
        # print(len(train_dataset))
    train_dataloader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=True
    )

    test_dataset = CUB(
            path,
            train=False,
            transform=test_transforms,
            target_transform=None
        )

    test_dataloader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=True
    )
    return train_dataloader,test_dataloader

# %% [markdown]
# ### 图像大小

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
import numpy as np


# 存储每个学习率下的损失和准确率
lr_train_losses = []
lr_train_accuracies = []
lr_val_losses = []
lr_val_accuracies = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 训练模型
num_epochs = 26
lrs = [112,224,448,560]
print(lrs)
for lr in lrs:
    print(f'Training with batch size: {lr}')
    print(type(lr))
    #train_dataloader,test_dataloader=dataloader(lr,32)
    time1 = time.time()
    IMAGE_SIZE = lr
    TRAIN_MEAN = [0.48560741861744905, 0.49941626449353244, 0.43237713785804116]
    TRAIN_STD = [0.2321024260764962, 0.22770540015765814, 0.2665100547329813]
    TEST_MEAN = [0.4862169586881995, 0.4998156522834164, 0.4311430419332438]
    TEST_STD = [0.23264268069040475, 0.22781080253662814, 0.26667253517177186]

    path = 'CUB_200_2011/CUB_200_2011'
    train_transforms = transforms.Compose([
            transforms.ToCVImage(),
            transforms.RandomResizedCrop(IMAGE_SIZE),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(TRAIN_MEAN, TRAIN_STD)
        ])
    
    test_transforms = transforms.Compose([
    transforms.ToCVImage(),
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(TEST_MEAN,TEST_STD)
    ])
    train_dataset = CUB(
            path,
            train=True,
            transform=train_transforms,
            target_transform=None
        )
        # print(len(train_dataset))
    train_dataloader = DataLoader(
        train_dataset,
        batch_size=32,
        num_workers=4,
        shuffle=True
    )

    test_dataset = CUB(
            path,
            train=False,
            transform=test_transforms,
            target_transform=None
        )

    test_dataloader = DataLoader(
        test_dataset,
        batch_size=32,
        num_workers=4,
        shuffle=True
    )
    # 加载预训练的ResNet-18模型
    model = models.resnet18(pretrained=True)
    num_ftrs = model.fc.in_features
    print(num_ftrs)
    model.fc = nn.Linear(num_ftrs, 200)  # 将输出层大小设置为200
    model = model.to(device)
    # 假设 model, train_dataloader, test_dataloader 已经定义好了
    # 定义损失函数和优化器
    criterion = nn.CrossEntropyLoss()
    parameter=model.parameters()
    optimizer = optim.SGD(parameter, lr=0.001, momentum=0.9)
    # 初始化变量用于存储损失和精度数据
    train_losses, train_accuracies,val_losses, val_accuracies = [],[], [], []
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                dataloader = train_dataloader
                data_len = len(dataloader.dataset)
                model.train()
            else:
                dataloader = test_dataloader
                data_len = len(dataloader.dataset)
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / data_len
            epoch_acc = (running_corrects.double() / data_len).cpu().item()

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase == 'train':
                train_losses.append(epoch_loss)
                train_accuracies.append(epoch_acc)
            else:
                val_losses.append(epoch_loss)
                val_accuracies.append(epoch_acc)
    # 将每个学习率下的整体损失和准确率存储起来
    lr_train_losses.append(train_losses)
    lr_train_accuracies.append(train_accuracies)
    lr_val_losses.append(val_losses)
    lr_val_accuracies.append(val_accuracies)
# 绘制损失和精度图
# 绘制每个学习率下的损失和准确率图
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
for i, lr in enumerate(lrs):
    axes[0, 0].plot(lr_train_losses[i], label=f'Image Size={lr}')
    axes[0, 1].plot(lr_train_accuracies[i], label=f'Image Size={lr}')
    axes[1, 0].plot(lr_val_losses[i], label=f'Image Size={lr}')
    axes[1, 1].plot(lr_val_accuracies[i], label=f'Image Size={lr}')

axes[0, 0].set_title('Training Loss')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()

axes[0, 1].set_title('Training Accuracy')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()

axes[1, 0].set_title('Validation Loss')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Loss')
axes[1, 0].legend()

axes[1, 1].set_title('Validation Accuracy')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].legend()

plt.tight_layout()
plt.show()
# Out:
# [112, 224, 448, 560]
# Training with batch size: 112
# <class 'int'>
# /data/dell/anaconda3/envs/qyh/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /data/dell/anaconda3/envs/qyh/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 512
# Epoch 1/26
# ----------
# train Loss: 5.1831 Acc: 0.0275
# val Loss: 4.5908 Acc: 0.0794
# Epoch 2/26
# ----------
# train Loss: 4.2313 Acc: 0.1350
# val Loss: 3.7626 Acc: 0.1750
# Epoch 3/26
# ----------
# train Loss: 3.5592 Acc: 0.2337
# val Loss: 3.2831 Acc: 0.2402
# Epoch 4/26
# ----------
# train Loss: 3.1221 Acc: 0.2960
# val Loss: 2.9494 Acc: 0.2948
# Epoch 5/26
# ----------
# train Loss: 2.8027 Acc: 0.3637
# val Loss: 2.7445 Acc: 0.3324
# Epoch 6/26
# ----------
# train Loss: 2.5711 Acc: 0.3957
# val Loss: 2.5348 Acc: 0.3687
# Epoch 7/26
# ----------
# train Loss: 2.3886 Acc: 0.4408
# val Loss: 2.4379 Acc: 0.3771
# Epoch 8/26
# ----------
# train Loss: 2.2423 Acc: 0.4621
# val Loss: 2.3241 Acc: 0.4042
# Epoch 9/26
# ----------
# train Loss: 2.0995 Acc: 0.5005
# val Loss: 2.2820 Acc: 0.4123
# Epoch 10/26
# ----------
# train Loss: 1.9777 Acc: 0.5379
# val Loss: 2.2310 Acc: 0.4284
# Epoch 11/26
# ----------
# train Loss: 1.8769 Acc: 0.5524
# val Loss: 2.1485 Acc: 0.4480
# Epoch 12/26
# ----------
# train Loss: 1.8025 Acc: 0.5689
# val Loss: 2.0720 Acc: 0.4646
# Epoch 13/26
# ----------
# train Loss: 1.7060 Acc: 0.5903
# val Loss: 2.0681 Acc: 0.4679
# Epoch 14/26
# ----------
# train Loss: 1.6287 Acc: 0.6064
# val Loss: 2.0249 Acc: 0.4745
# Epoch 15/26
# ----------
# train Loss: 1.6181 Acc: 0.6053
# val Loss: 2.0267 Acc: 0.4748
# Epoch 16/26
# ----------
# train Loss: 1.5361 Acc: 0.6315
# val Loss: 2.0250 Acc: 0.4788
# Epoch 17/26
# ----------
# train Loss: 1.4790 Acc: 0.6371
# val Loss: 2.0645 Acc: 0.4719
# Epoch 18/26
# ----------
# train Loss: 1.4315 Acc: 0.6565
# val Loss: 1.9842 Acc: 0.4869
# Epoch 19/26
# ----------
# train Loss: 1.3778 Acc: 0.6712
# val Loss: 2.0075 Acc: 0.4845
# Epoch 20/26
# ----------
# train Loss: 1.3277 Acc: 0.6805
# val Loss: 1.9498 Acc: 0.5010
# Epoch 21/26
# ----------
# train Loss: 1.2884 Acc: 0.6859
# val Loss: 1.9846 Acc: 0.4940
# Epoch 22/26
# ----------
# train Loss: 1.2445 Acc: 0.7080
# val Loss: 1.9938 Acc: 0.4912
# Epoch 23/26
# ----------
# train Loss: 1.2174 Acc: 0.7089
# val Loss: 2.0423 Acc: 0.4843
# Epoch 24/26
# ----------
# train Loss: 1.1819 Acc: 0.7221
# val Loss: 1.9590 Acc: 0.5022
# Epoch 25/26
# ----------
# train Loss: 1.1530 Acc: 0.7274
# val Loss: 1.9660 Acc: 0.5017
# Epoch 26/26
# ----------
# train Loss: 1.1419 Acc: 0.7251
# val Loss: 2.0220 Acc: 0.4934
# Training with batch size: 224
# <class 'int'>
# 512
# Epoch 1/26
# ----------
# train Loss: 5.2112 Acc: 0.0229
# val Loss: 4.7594 Acc: 0.0828
# Epoch 2/26
# ----------
# train Loss: 4.4785 Acc: 0.1243
# val Loss: 3.9171 Acc: 0.2009
# Epoch 3/26
# ----------
# train Loss: 3.7867 Acc: 0.2437
# val Loss: 3.3136 Acc: 0.2994
# Epoch 4/26
# ----------
# train Loss: 3.2916 Acc: 0.3368
# val Loss: 2.9001 Acc: 0.3768
# Epoch 5/26
# ----------
# train Loss: 2.9225 Acc: 0.4101
# val Loss: 2.5641 Acc: 0.4336
# Epoch 6/26
# ----------
# train Loss: 2.6363 Acc: 0.4648
# val Loss: 2.3275 Acc: 0.4788
# Epoch 7/26
# ----------
# train Loss: 2.4039 Acc: 0.5057
# val Loss: 2.1070 Acc: 0.5112
# Epoch 8/26
# ----------
# train Loss: 2.1859 Acc: 0.5509
# val Loss: 1.9680 Acc: 0.5361
# Epoch 9/26
# ----------
# train Loss: 2.0331 Acc: 0.5739
# val Loss: 1.8566 Acc: 0.5589
# Epoch 10/26
# ----------
# train Loss: 1.9120 Acc: 0.5926
# val Loss: 1.7472 Acc: 0.5728
# Epoch 11/26
# ----------
# train Loss: 1.7856 Acc: 0.6223
# val Loss: 1.6514 Acc: 0.5844
# Epoch 12/26
# ----------
# train Loss: 1.7129 Acc: 0.6346
# val Loss: 1.6101 Acc: 0.5930
# Epoch 13/26
# ----------
# train Loss: 1.6490 Acc: 0.6428
# val Loss: 1.5363 Acc: 0.6130
# Epoch 14/26
# ----------
# train Loss: 1.5101 Acc: 0.6772
# val Loss: 1.5117 Acc: 0.6163
# Epoch 15/26
# ----------
# train Loss: 1.4796 Acc: 0.6812
# val Loss: 1.4636 Acc: 0.6234
# Epoch 16/26
# ----------
# train Loss: 1.4160 Acc: 0.6990
# val Loss: 1.4171 Acc: 0.6336
# Epoch 17/26
# ----------
# train Loss: 1.3380 Acc: 0.7095
# val Loss: 1.3701 Acc: 0.6429
# Epoch 18/26
# ----------
# train Loss: 1.2919 Acc: 0.7239
# val Loss: 1.3839 Acc: 0.6433
# Epoch 19/26
# ----------
# train Loss: 1.2595 Acc: 0.7246
# val Loss: 1.3252 Acc: 0.6565
# Epoch 20/26
# ----------
# train Loss: 1.1958 Acc: 0.7406
# val Loss: 1.3265 Acc: 0.6526
# Epoch 21/26
# ----------
# train Loss: 1.1567 Acc: 0.7477
# val Loss: 1.2937 Acc: 0.6559
# Epoch 22/26
# ----------
# train Loss: 1.1379 Acc: 0.7568
# val Loss: 1.3167 Acc: 0.6452
# Epoch 23/26
# ----------
# train Loss: 1.0752 Acc: 0.7693
# val Loss: 1.2940 Acc: 0.6607
# Epoch 24/26
# ----------
# train Loss: 1.0437 Acc: 0.7703
# val Loss: 1.2522 Acc: 0.6610
# Epoch 25/26
# ----------
# train Loss: 1.0307 Acc: 0.7763
# val Loss: 1.2822 Acc: 0.6603
# Epoch 26/26
# ----------
# train Loss: 0.9624 Acc: 0.7908
# val Loss: 1.2467 Acc: 0.6698
# Training with batch size: 448
# <class 'int'>
# 512
# Epoch 1/26
# ----------
# train Loss: 5.2786 Acc: 0.0143
# val Loss: 5.0678 Acc: 0.0324
# Epoch 2/26
# ----------
# train Loss: 4.8922 Acc: 0.0517
# val Loss: 4.6910 Acc: 0.0687
# Epoch 3/26
# ----------
# train Loss: 4.4890 Acc: 0.1006
# val Loss: 4.3160 Acc: 0.1320
# Epoch 4/26
# ----------
# train Loss: 4.1131 Acc: 0.1580
# val Loss: 3.9272 Acc: 0.1973
# Epoch 5/26
# ----------
# train Loss: 3.8007 Acc: 0.2171
# val Loss: 3.6259 Acc: 0.2508
# Epoch 6/26
# ----------
# train Loss: 3.5254 Acc: 0.2719
# val Loss: 3.3843 Acc: 0.2910
# Epoch 7/26
# ----------
# train Loss: 3.2881 Acc: 0.3262
# val Loss: 3.1253 Acc: 0.3495
# Epoch 8/26
# ----------
# train Loss: 3.0847 Acc: 0.3679
# val Loss: 2.9222 Acc: 0.3857
# Epoch 9/26
# ----------
# train Loss: 2.8881 Acc: 0.4061
# val Loss: 2.7295 Acc: 0.4187
# Epoch 10/26
# ----------
# train Loss: 2.7201 Acc: 0.4381
# val Loss: 2.6093 Acc: 0.4325
# Epoch 11/26
# ----------
# train Loss: 2.5909 Acc: 0.4578
# val Loss: 2.4557 Acc: 0.4632
# Epoch 12/26
# ----------
# train Loss: 2.4596 Acc: 0.4888
# val Loss: 2.3340 Acc: 0.4953
# Epoch 13/26
# ----------
# train Loss: 2.3440 Acc: 0.5163
# val Loss: 2.1953 Acc: 0.5200
# Epoch 14/26
# ----------
# train Loss: 2.2292 Acc: 0.5429
# val Loss: 2.0834 Acc: 0.5411
# Epoch 15/26
# ----------
# train Loss: 2.1274 Acc: 0.5624
# val Loss: 2.0199 Acc: 0.5478
# Epoch 16/26
# ----------
# train Loss: 2.0396 Acc: 0.5782
# val Loss: 1.9002 Acc: 0.5652
# Epoch 17/26
# ----------
# train Loss: 1.9356 Acc: 0.5974
# val Loss: 1.8432 Acc: 0.5865
# Epoch 18/26
# ----------
# train Loss: 1.8602 Acc: 0.6166
# val Loss: 1.7491 Acc: 0.5935
# Epoch 19/26
# ----------
# train Loss: 1.8100 Acc: 0.6256
# val Loss: 1.6728 Acc: 0.6187
# Epoch 20/26
# ----------
# train Loss: 1.7212 Acc: 0.6416
# val Loss: 1.6437 Acc: 0.6149
# Epoch 21/26
# ----------
# train Loss: 1.6674 Acc: 0.6662
# val Loss: 1.6001 Acc: 0.6293
# Epoch 22/26
# ----------
# train Loss: 1.6335 Acc: 0.6620
# val Loss: 1.5895 Acc: 0.6200
# Epoch 23/26
# ----------
# train Loss: 1.5871 Acc: 0.6635
# val Loss: 1.5008 Acc: 0.6415
# Epoch 24/26
# ----------
# train Loss: 1.5050 Acc: 0.6834
# val Loss: 1.4555 Acc: 0.6524
# Epoch 25/26
# ----------
# train Loss: 1.4551 Acc: 0.7019
# val Loss: 1.4424 Acc: 0.6526
# Epoch 26/26
# ----------
# train Loss: 1.4059 Acc: 0.7087
# val Loss: 1.4346 Acc: 0.6572
# Training with batch size: 560
# <class 'int'>
# 512
# Epoch 1/26
# ----------
# train Loss: 5.3146 Acc: 0.0075
# val Loss: 5.1538 Acc: 0.0231
# Epoch 2/26
# ----------
# train Loss: 5.0377 Acc: 0.0352
# val Loss: 4.8686 Acc: 0.0419
# Epoch 3/26
# ----------
# train Loss: 4.7210 Acc: 0.0614
# val Loss: 4.5937 Acc: 0.0725
# Epoch 4/26
# ----------
# train Loss: 4.4125 Acc: 0.0994
# val Loss: 4.3101 Acc: 0.1087
# Epoch 5/26
# ----------
# train Loss: 4.1259 Acc: 0.1577
# val Loss: 4.0360 Acc: 0.1567
# Epoch 6/26
# ----------
# train Loss: 3.8757 Acc: 0.2002
# val Loss: 3.8151 Acc: 0.1921
# Epoch 7/26
# ----------
# train Loss: 3.6515 Acc: 0.2437
# val Loss: 3.6207 Acc: 0.2297
# Epoch 8/26
# ----------
# train Loss: 3.4544 Acc: 0.2789
# val Loss: 3.4499 Acc: 0.2561
# Epoch 9/26
# ----------
# train Loss: 3.2893 Acc: 0.3078
# val Loss: 3.2203 Acc: 0.3029
# Epoch 10/26
# ----------
# train Loss: 3.1331 Acc: 0.3437
# val Loss: 3.1080 Acc: 0.3241
# Epoch 11/26
# ----------
# train Loss: 2.9840 Acc: 0.3687
# val Loss: 2.9681 Acc: 0.3457
# Epoch 12/26
# ----------
# train Loss: 2.8481 Acc: 0.3956
# val Loss: 2.8368 Acc: 0.3754
# Epoch 13/26
# ----------
# train Loss: 2.7385 Acc: 0.4216
# val Loss: 2.7186 Acc: 0.4047
# Epoch 14/26
# ----------
# train Loss: 2.6323 Acc: 0.4453
# val Loss: 2.6114 Acc: 0.4223
# Epoch 15/26
# ----------
# train Loss: 2.5174 Acc: 0.4683
# val Loss: 2.5433 Acc: 0.4367
# Epoch 16/26
# ----------
# train Loss: 2.4332 Acc: 0.4815
# val Loss: 2.4199 Acc: 0.4620
# Epoch 17/26
# ----------
# train Loss: 2.3369 Acc: 0.5092
# val Loss: 2.2735 Acc: 0.4803
# Epoch 18/26
# ----------
# train Loss: 2.2656 Acc: 0.5189
# val Loss: 2.2596 Acc: 0.4902
# Epoch 19/26
# ----------
# train Loss: 2.1728 Acc: 0.5472
# val Loss: 2.1621 Acc: 0.5043
# Epoch 20/26
# ----------
# train Loss: 2.0997 Acc: 0.5539
# val Loss: 2.1711 Acc: 0.5002
# Epoch 21/26
# ----------
# train Loss: 2.0366 Acc: 0.5719
# val Loss: 1.9978 Acc: 0.5257
# Epoch 22/26
# ----------
# train Loss: 1.9422 Acc: 0.5883
# val Loss: 2.0053 Acc: 0.5335
# Epoch 23/26
# ----------
# train Loss: 1.8820 Acc: 0.6069
# val Loss: 1.9653 Acc: 0.5411
# Epoch 24/26
# ----------
# train Loss: 1.8172 Acc: 0.6236
# val Loss: 1.9407 Acc: 0.5452
# Epoch 25/26
# ----------
# train Loss: 1.7579 Acc: 0.6370
# val Loss: 1.7963 Acc: 0.5856
# Epoch 26/26
# ----------
# train Loss: 1.7117 Acc: 0.6365
# val Loss: 1.8556 Acc: 0.5715
